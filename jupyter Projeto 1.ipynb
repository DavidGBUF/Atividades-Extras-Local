# %% [markdown]
# Resposta:

# %% [markdown]
# # Projeto 1
# Projete um sistema de memória que possui 13 pinos de endereços e um barramento de dados (BD) que transporta 2 palavras por vez. O BD não pode exceder 64 bits e a palavra deve ser maior que a célula da memória. A memória deve ter capacidade de 8 Gbits. Depois do projeto, indique qual é o tamanho da palavra, da célula, do BD e do barramento de endereços, e desenhe o chip.

# %%
from IPython.display import Image
Image(filename='Projeto1.png')

# %% [markdown]
#  A seguinte memória serve para o problema, possui 1G de endereços (ou células) com cada uma guardando 8 bits, ela possui 16 bancos e a organização de suas células é em forma de matriz, totalizando: 2¹³linhas (Pois são 13 pinos de endereço) X 2¹³ de colunas X 2^4 (16 na base 2)= 2^30 células X 8 (tamanho da célula).
#
# Tamanho Célula= 8 bits
# Tamanho da palavra=16 bits (Supondo que ela é formada por duas células)
# Tamanho do BD= 32 Bits
# Tamanho do BE=30 Bits (pois são 30 bits para representar 1G de células )

# %% [markdown]
# =================================================================================

# %% [markdown]
# # Projeto 2
# Projete um sistema de memória que possui 16 linhas de dados (BD). Os pinos de endereço precisam ser menores que 14. A memória deve ter capacidade de 32 Gbits. Justifique cada decisão do projeto. Desenhe o chip. Qual é o tamanho do barramento de endereços?

# %% [markdown]
# Resposta:

# %%
from IPython.display import Image
Image(filename='Projeto2.png')

# %% [markdown]
# A Seguinte mémoria possui 13 pinos de entrada, é organizada em forma de matriz e possui 32 bancos
# Como o BD só pode transportar 16 bits, o tamanho das células e palavras estam limitadas a 16 bits
# 2¹³(linhas) X 2¹³(colunas) X 2^5(32 na base 2, advem do numero de bancos) X 2^4(tamanho célula)= 2^35 Bits= 32Gbits.
# Para expressar todos os 13 pinos de endereços, basta que o BE tenha 13 bits de tamanho
